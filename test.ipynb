# %%
import numpy as np

# %%
a = np.array([1,2], dtype=int).tolist()

b = (np.array([2,3], dtype=int) - 1).tolist()

# %%
a == b
# Out:
# True

# %%
if a == b:
    print('yo')
# Out:
# yo

# %%
d = {}
d[tuple(a)] = "yo"

# %%
d
# Out:
# {(1, 2): 'yo'}

# %%
num_colors = 3
ar = num_colors ** np.arange(0,3)

ar
# Out:
# array([1, 3, 9])
