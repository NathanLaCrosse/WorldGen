# %%
# Bad intersection code for temporary work...
def intersect(a1, a2):
    dest = []

    for a in a1:
        if a in a2:
            dest.append(a)

    return dest

# %%
def intersect_bit_states(b1, b2):
    return b1 & b2

# %%
# %%timeit
a1 = list(range(100))
a2 = list(range(100))

intersect(a1, a2)
# Out:
# 88.9 μs ± 2.02 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
a1 = 0b01110010100111001010010010101010001001010101010101010010101010101010100101010101010111001010011100101001001010101000100101010101010101001010101010101010010101010101
a2 = 0b10110010011001010011010010101010001001010101010101110010101010101010100101010101010111001010011100101001001010101000100101010101010101001010101010101010010101010101

intersect_bit_states(a1, a2)
# Out:
# 245 ns ± 34.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
len(bin(0b01110010100111001010010010101010001001010101010101010010101010101010100101010101010111001010011100101001001010101000100101010101010101001010101010101010010101010101))
# Out:
# 165

# %%
import numpy as np

# %%
# %%timeit
a1 = list(range(20))

choice = np.random.choice(np.array(a1))
# Out:
# 19.4 μs ± 1.32 μs per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%timeit

a1 = 0b011100101001110010101
weights = np.array([20, 2, 1, 50, 4, 32, 20, 19, 8, 23, 1, 20, 42, 56, 78, 20, 10, 30, 50, 20, 21])[::-1]
# bit_ar = np.zeros(21)
args = np.arange(21)
p = np.zeros(21)

c = a1
for i in range(21):
    p[i] = (1 & c) * weights[i]
    c = c >> 1

np.random.choice(args, p=p/p.sum())
# Out:
# array([21.,  0., 50.,  0., 10.,  0.,  0., 56., 42., 20.,  0.,  0.,  8.,
#         0., 20.,  0.,  0., 50.,  1.,  2.,  0.])

# %%
2**5 - 1
# Out:
# 31

# %%
bin(31)
# Out:
# '0b11111'
